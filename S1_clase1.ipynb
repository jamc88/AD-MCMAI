# %% [markdown]
# # Clase 1 - Semana 1
# #### Tópicos Selectos De Matemáticas Aplicadas II: Análisis de Datos con Python

# %% [markdown]
# ### Tipos de datos

# %% [markdown]
# Los tipos primitivos o tipos de datos en python son las estructuras de datos más elementales del lenguaje de programación. Son los componentes básicos para tratar todo tipo de datos o variables.
#
# Python tiene cuatro tipos primitivos:
#
# - Los tipos de variables enteros en Python **int** se utilizan para representar números enteros.
#
# - Los tipos de datos flotantes en Python **float** se utilizan para representar números con decimales.
#
# - Los tipos de datos **string** son un arreglo de caracteres que forman cadenas para formar una oración.
#
# - Los tipos  booleanos en python **bool** son tipos de datos binarios, es decir que pueden tomar los valores: Verdadero (True) y Falso (False). Son útiles para expresiones con condicionales y de comparaciones.

# %%
a = 3
b = 4.5
c = 'alumno'
d = False

# %% [markdown]
# ### Listas

# %% [markdown]
# Una lista es una secuencia de valores. Es un tipo de contenedor usado para almacenar un número indefinido de datos arbitrarios del mismo tipo o de tipos distintos.

# %%
lista1 = [3,4,5] 
lista2 = ['uno', 'dos', 'tres']
lista3 = ['uno', 2, 3.14, [10, 20, 30]]

# %% [markdown]
# Las listas en Python tienen las siguientes propiedades:
#
# * Son ordenadas: cada elemento dentro de la lista está indexado y mantiene el orden definido.
#
# * Permiten elementos duplicados: las listas pueden tener elementos con el mismo valor.
#
# * Las listas pueden anidar, es decir, contener una lista dentro de la otra.
#
# * Son mutables: podemos editar, eliminar o agregar elementos en una lista existente (.append(), .remove(),lista1[x] = y)

# %%
lista1[0]=7

# %%
lista1.append(10)

# %%
lista1.remove(4)

# %%
lista1
# Out:
# [7, 5, 10]

# %% [markdown]
# ### Cadenas de Texto

# %% [markdown]
# Las cadenas de texto de Python son inmutables; no se pueden modificar:

# %%
a ='esto es una cadena'
a
# Out:
# 'esto es una cadena'

# %%
a[8]
# Out:
# 'u'

# %% [markdown]
# Si necesitamos modificar una cadena de texto, tenemos que utilizar una función que cree una nueva cadena, como la función **.replace()** para cadenas de texto:

# %%
b = a.replace('cadena', 'cadena grande')

# %%
b
# Out:
# 'esto es una cadena grande'

# %% [markdown]
# Muchos objetos de Python se pueden transformar en una cadena de texto utilizando la función **str()**

# %%
str(7.4)
# Out:
# '7.4'

# %% [markdown]
# Sumar dos cadenas las concatena y produce una nueva:

# %%
a = 'primera mitad'
b = ' y segunda mitad'

# %%
a+b
# Out:
# 'primera mitad y segunda mitad'

# %% [markdown]
# ### Operadores binarios

# %% [markdown]
# ![Captura%20de%20pantalla%202025-05-26%20a%20la%28s%29%209.16.39%E2%80%AFp.m..png](attachment:Captura%20de%20pantalla%202025-05-26%20a%20la%28s%29%209.16.39%E2%80%AFp.m..png)

# %% [markdown]
# ![Captura%20de%20pantalla%202025-05-26%20a%20la%28s%29%209.19.30%E2%80%AFp.m..png](attachment:Captura%20de%20pantalla%202025-05-26%20a%20la%28s%29%209.19.30%E2%80%AFp.m..png)

# %%
2**3*(9+123)
# Out:
# 1056

# %% [markdown]
# Ejemplos:

# %%
a = 7
b = 10

a > b
# Out:
# False

# %% [markdown]
# Supongan que queremos resolver varias ecuaciones cuadráticas de la forma:
#
# $$
# ax^2 + bx+c=0,
# $$
#
# entonces, tenemos las soluciones:
#
# $$
# x_1 = \frac{-b-\sqrt{b^2-4ac}}{2a}
# $$
# y
#
# $$
# x_2 = \frac{-b+\sqrt{b^2-4ac}}{2a}
# $$
# para $a,b,c\in\mathbb{R}.$

# %% [markdown]
# Resolver
#
# $$
# x^2 + x-1 =0.
# $$
#
#  Almacenamos los valores de $a, b $ y $ c $.

# %%
a=-1
b=1
c=11

# %%
import math

# %%
x1=((-b)+math.sqrt(b**2-4*a*c))/2*a
x2=((-b)-math.sqrt(b**2-4*a*c))/2*a

# %%
x1
# Out:
# -2.8541019662496847

# %%
x2
# Out:
# 3.8541019662496847

# %%
import math 

#math.sqrt()

# %% [markdown]
# # Control de Flujo

# %% [markdown]
# Python tiene varias palabras clave internas para lógica condicional, bucles y otros conceptos estándares de control de flujo, que pueden encontrarse en otros lenguajes de programación.

# %% [markdown]
# ## if, elif y else

# %% [markdown]
# La sentencia **if** es uno de los tipos de sentencia de control de flujo más conocidos. Comprueba una condición que, si es *True*, evalúa el código del bloque que le sigue:

# %%
x = -56

if x < 0:
    print('x es negativo')
# Out:
# x es negativo

# %% [markdown]
# Una sentencia *if* puede ir seguida de manera opcional por uno o más bloques **elif** y un bloque multifuncional **else** si todas las condiciones son False:

# %%
x = 1

# %%
if x < 0:
    print('x es negativo')
elif x==0:
    print('x es igual a cero')
elif 0 < x < 15:
    print('x es positivo pero menor que 15')
else:
    print('x es positivo mayor o igual a 15')
# Out:
# x es positivo pero menor que 15

# %% [markdown]
# Dada una ecuación cuadrática $$ax^2 + bx+c=0,$$ escribe un código que:
#
# - Imprima las raíces reales si existen.
#
# - Indique si las raíces son complejas si el discriminante es negativo.

# %%
a=1
b=4
c=5

# %%
D = b**2 - 4*a*c


if D > 0:
    x1 = (-b + math.sqrt(D)) / (2*a)
    x2 = (-b - math.sqrt(D)) / (2*a)
    print("Dos raíces reales:", x1, x2)
elif D == 0:
    x = -b / (2*a)
    print("Una raíz real doble:", x)
else:
    print("Raíces complejas")
# Out:
# Raíces complejas

# %% [markdown]
# La función **input()** sirve para pedirle datos al usuario. Es una forma de interacción entre el programa y la persona que lo ejecuta.

# %%
n = int(input("Ingresa un número: "))

if n > 0:
    print("El número es positivo")
elif n < 0:
    print("El número es negativo")
else:
    print("El número es cero")
# Out:
# Ingresa un número: 3
# El número es positivo
